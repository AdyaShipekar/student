# %% [raw]
# ---
# layout: post
# toc: True
# title: CSSE1 Final Blog
# description: This blog encompasses everything I have learned in computer science so far.
# permalink: /github/pages/csse-1-final-blog
# author: Adya Shipekar
# ---

# %% [markdown]
# ## **CSSE1 Final Blog**
#
# ### **Personal Growth**
#
# I have improved so much, both as a coder and an innovator, since the beginning of this trimester. Through my learning about basic coding tools, fundamental topics in JavaScript, and ability to code both simple and more complex games (from Animated Background to our complicated 6-level mansion game), I have gathered so much knowledge to use in future coding endeavors.
#
# Beyond academics, I have had so much fun in my CSSE group. Coding with my group and bringing games and characters to life using classroom ideation was a truly unique experience.
#
# Being scrum master of my group helped me gain critical leadership skills and opportunities. Managing the class and overseeing the Quest of Spook also improved my ability to collaborate with others.
#
# At the start of the year (near the end of Sprint 1), we graded ourselves using a checklist/rubric. Although I gave myself a pretty high score, I now realize how limited my knowledge of the vast realm of coding was. I have the rubric below, with self-graded scores on where I think I was at the start of the trimester compared to where I am now (both in my coding abilities and my ability to lead my group and my class).
#
#
# | Skill                  | Mastered (Y/N) | Beginning Rank (1-5) | End Rank (1-5) | Notes/Evidence |
# |-------------------------|----------------|-----------------|-----------------|---------------------|
# | 🎯 **Core Behaviors**   |                |                 |                 | |
# | Attendance              | [Y]            | 4               | 5               | I have consistently showed up to class on time. |
# | Work Habits             | [Y]            | 3               | 4               | At the start of the trimester, I completed my work but did not put as much effort in as I strive to do now. However, there is always room for improvement :) |
# | Behavior                | [Y]            | 3              | 5               | Over the course of the trimester, I've learned so much about how to communicate effectively with my peers and Mr. Mortenson. |
# | Timeliness              | [Y]            | 4               | 5               | I always complete all my work on time. |
# | 💻 **Technical Skills** |                |                 |                 | |
# | Tech/Cyber Sense        | [Y]            | 2               | 4               | Initially, my technology/coding skills were limited and I struggled with completing simple tasks. Over this trimester, I've improved so much and learned so many new things. |
# | Tech/Cyber Talk         | [Y]            | 2               | 4               | At the beginning of the trimester, I wouldn't have been able to speak on my growth and what I've learned. |
# | Tech Growth             | [Y]            | 2               | 3               | There's always room for growth! |
# | 🤝 **Collaboration**    |                |                 |                 | |
# | Advocacy                | [Y]            | 2               | 4               | Over this trimester, managing the Quest of Spook has helped with my advocacy and ability to help my peers. |
# | Communication & Collab  | [Y]            | 2               | 5               | I can pitch an idea formally and collaborate with peers on an idea. |
# | 🎨 **Professional Skills** |            |                 |                 | |
# | Integrity               | [Y]            | 5               | 5               | Always remained on task and completed my work. |
# | Organization            | [Y]            | 4               | 5               | Always organized and improved on being able to understand what was expected of me. |
# | 📈 **TOTALS**           |                | 33               | 49               | |
# | 🎯 **AVERAGE SCORE**    |                | 3             | 4.5             | |
#
# <br>
#
# ### **Sprints 1-3**
#
# #### <u>Sprint 1: Tools and Equipment</u>
#
# [Personal Troubleshooting Guide](https://adyashipekar.github.io/student/tools/blog)
#
# The troubleshooting Guide compasses everything I learned in the sprint and set me up for a higher level of learning/coding.
#
# #### <u>Sprint 2: Hacks and JavaScript Fundamentals</u>
#
# [Team Hacks](https://adyashipekar.github.io/code-constellations/hacks)
#
# One of my favorite hacks was the Snake Game, because it was the one our team spent the most time on and made the most edits to. The most important thing I recall from this quest was being able to deploy an interactive website. My key contribution to the quest was coding the main page of Code Constellations and linking all hacks.
#
# [Team Lessons](https://adyashipekar.github.io/code-constellations/fundamentals)
#
# Our team lessons were well-planned and well-executed. I was the scrum master and helped ensure everything went smoothly both before and during our presentation.
#
# [Kanban Board](https://github.com/users/AdyaShipekar/projects/3)
#
# Homeworks (in Categories)
#
# #### <u>Sprint 3: Gamify Quest (Quest of Spook)</u>
#
# [Kanban Board](https://github.com/users/AdyaShipekar/projects/4)
#
# Contributions:
# - Pull Requests
# - Scrum Master
# - Coded the main character movement
# - Initial collision detection system
# - Coded all items within the pantry
#
# Key Learning:
# - Collaboration (w/ other groups)
# - OOP (classes and constructors for each sprite)
# - Collision Detection (and conditionals to define actions for these)
# - Ideation (classroom ideation process to come up w/ game theme)
#
# <br>
#
# ### **N@tM**
#
# Night at the Museum was an amazing experience and a chance to show off our Gamify Quest.
#
# *Things that went well:* No bugs in the game, Audience understood game, Interactive and fun, Organized, Well-Presented, Got Good Feedback
#
# *Improvements:* Projecting to an audience more (speaking skills), Ability to get the audience to connect w/ our game, Presenting more theory/code behind our work
#
# Some [Comments](https://pages.opencodingsociety.com/gamify/mansionGame) (on our MicroBlog!)
# - Proof I was there because the comments are from my computer :)
# - I was the one who screenshared our game!
#
# ![image.png](attachment:image.png)
# ![image-2.png](attachment:image-2.png)
#
# <br>
#
# ### **Future Learning**
#
# Some Key Goals:
# - Improve the Quest of Spook game (main world locks, progress checks, expand on levels)
# - Complete more Hacks (Tic Tac Toe, Cookie Clicker, etc sounded interesting!)
#
# Learning:
# - Advanced data structures + algorithms for parsing (how to code these)
# - Backend + Frontend Development
#
# <br>
#
# ### **Analytics**
#
# [Analytics](https://pages.opencodingsociety.com/dashboard)
#
# <br>
#
# ### **Something Cool**
#
# [Quotes](https://adyashipekar.github.io/code-constellations/github/pages/quotes)
